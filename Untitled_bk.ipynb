# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# ## 获取lotID

# %%
dfm = pd.read_excel('./t_mcs.xls')  #读取lotID在mcs的搬送记录，用来统计搬送时间
Lotid = dfm['LOTID'][0]
print('本批lot为： %s 。' % Lotid)
# Out:
# 本批lot为： L2E9306A5AA 。

# %% [markdown]
# ## 计算开始时间

# %%
dfcm = pd.read_excel('./c_mcs.xls')  #读取cst在mcs的搬送记录，为了获取真正的开始时间，创建往2AUU01搬送job的时间
dfcm['TIME'] = pd.to_datetime(dfcm['TIME'])
AUU_start = dfcm[(dfcm['DEST MACHINE'] == '2AUU01') & (dfcm['STATE'] == 'CREATED')]['TIME']
print('%s 进入Array时间为 %s 。' % (Lotid ,AUU_start[0]))
# Out:
# L2E9306A5AA 进入Array时间为 2019-03-06T19:16:58.909000000 。

# %% [markdown]
# # 计算transfertime

# %%
dfm = dfm[['TIME', 'TRANSPORTJOBID', 'STATE']]  #只选取我们需要用到的三列'TIME', 'TRANSPORTJOBID', 'STATE'
dfm.head()
# Out:
#                       TIME          TRANSPORTJOBID      STATE
# 0  2019-03-06 19:56:35.161  R20190306195634-AN0348    CREATED
# 1  2019-03-06 19:57:35.788  R20190306195634-AN0348  COMPLETED
# 2  2019-03-06 23:03:15.816  U20190306230315-AN0348    CREATED
# 3  2019-03-06 23:04:08.227  U20190306230315-AN0348  COMPLETED
# 4  2019-03-06 23:15:20.178  R20190306231519-AN0348    CREATED

# %% [markdown]
# ## 删除TRANSPORTJOBID唯一的记录

# %%
l = dfm['TRANSPORTJOBID']
dfmcount = pd.DataFrame([l.value_counts()]).T  # 统计每个TRANSPORTJOBID出现的次数
list_one = dfmcount[dfmcount['TRANSPORTJOBID'] == 1].index.tolist()  # 如果出现次数是1，记录下来下一步准备删除
list_one
# Out:
# ['R20190401023712-AN0348',
#  'R20190313185350-AN0348',
#  'R20190402112130-AN0348',
#  'R20190401125431-AN0348',
#  'R20190326214050-AN0348',
#  'R20190321010047-AN0348',
#  'R20190402140018-AN0348',
#  'R20190319132458-AN0348',
#  'R20190320212858-AN0348',
#  'R20190329204808-AN0348',
#  'R20190402200512-AN0348',
#  'R20190319071214-AN0348',
#  'R20190321161656-AN0348',
#  'R20190330152104-AN0348',
#  'R20190402165251-AN0348',
#  'R20190312161747-AN0348']

# %%
dfm=dfm[-dfm.TRANSPORTJOBID.isin(list_one)]  # 删除TRANSPORTJOBID是唯一的记录
dfm.head()
# Out:
#                       TIME          TRANSPORTJOBID      STATE
# 0  2019-03-06 19:56:35.161  R20190306195634-AN0348    CREATED
# 1  2019-03-06 19:57:35.788  R20190306195634-AN0348  COMPLETED
# 2  2019-03-06 23:03:15.816  U20190306230315-AN0348    CREATED
# 3  2019-03-06 23:04:08.227  U20190306230315-AN0348  COMPLETED
# 4  2019-03-06 23:15:20.178  R20190306231519-AN0348    CREATED

# %% [markdown]
# ## 计算每次搬送的时间 求和即为总的搬送时间(这里没算上CST从STK15往AUU搬的时间，时间平均都在60S内，对总的来说微乎其微，所以舍去了)

# %%
dfm_time = pd.DataFrame()  # 新建一个表格用来处理搬送时间
# 原表中‘STATE’是‘CREATED’的那些行的时间提取出来
dfm_time['created'] = dfm[dfm['STATE'] == 'CREATED']['TIME'].tolist()
# 原表中‘STATE’不是‘CREATED’（也就是‘COMPLETED’或者是‘TERMINATED’）的那些行的时间提取出来
dfm_time['ended'] = dfm[dfm['STATE'] != 'CREATED']['TIME'].tolist()
# 转换成时间格式，为下一步计算差值以及总时间做准备
dfm_time = dfm_time.astype(np.datetime64)
# 计算每次搬送的时间，并求和
dfm_time['delta'] = dfm_time['ended'] - dfm_time['created']
trantime = dfm_time['delta'].sum()
print('%s 在 Array 搬送总时间为： %s' % (Lotid, trantime))
# Out:
# L2E9306A5AA 在 Array 搬送总时间为： 1 days 13:57:54.338000

# %% [markdown]
# # 计算总时长，制程时间

# %%
dfo = pd.read_excel('./t_oic.xls')
dfo = dfo[['EventTime', 'EventName', 'EQP ID']]                 # 只提取'EventTime', 'EventName'后续处理
dfo['EventTime'] = pd.to_datetime(dfo['EventTime'])   # 转换时间戳，便于后面的计算
dfo
# Out:
# WARNING *** file size (801968) not 512 + multiple of sector size (512)
#               EventTime          EventName  EQP ID
# 0   2019-04-03 18:01:55        MakeEmptied  2CFC01
# 1   2019-04-03 18:01:55    TransferProduct  2CFC01
# 2   2019-04-03 17:44:32                Cut  2CFC01
# 3   2019-04-03 17:41:34                Cut  2CFC01
# 4   2019-04-03 17:41:06    DeassignCarrier  2CFC01
# 5   2019-04-03 17:38:35                Cut  2CFC01
# 6   2019-04-03 17:35:32                Cut  2CFC01
# 7   2019-04-03 17:32:32                Cut  2CFC01
# 8   2019-04-03 17:29:35                Cut  2CFC01
# 9   2019-04-03 17:26:32                Cut  2CFC01
# 10  2019-04-03 17:23:47                Cut  2CFC01
# 11  2019-04-03 17:23:11    TransferProduct  2CFC01
# 12  2019-04-03 17:21:21                Cut  2CFC01
# 13  2019-04-03 17:12:44                Cut  2CFC01
# 14  2019-04-03 17:09:42                Cut  2CFC01
# 15  2019-04-03 17:06:43                Cut  2CFC01
# 16  2019-04-03 17:03:43                Cut  2CFC01
# 17  2019-04-03 17:00:43                Cut  2CFC01
# 18  2019-04-03 16:57:44                Cut  2CFC01
# 19  2019-04-03 16:54:46                Cut  2CFC01
# 20  2019-04-03 16:51:43                Cut  2CFC01
# 21  2019-04-03 16:49:11                Cut  2CFC01
# 22  2019-04-03 16:46:08                Cut  2CFC01
# 23  2019-04-03 16:42:42                Cut  2CFC01
# 24  2019-04-03 16:39:43                Cut  2CFC01
# 25  2019-04-03 16:36:43                Cut  2CFC01
# 26  2019-04-03 16:33:43                Cut  2CFC01
# 27  2019-04-03 16:30:43                Cut  2CFC01
# 28  2019-04-03 16:28:18                Cut  2CFC01
# 29  2019-04-03 16:26:20                Cut  2CFC01
# ..                  ...                ...     ...
# 848 2019-03-07 16:24:06           TrackOut  2AFC01
# 849 2019-03-07 14:32:03            TrackIn  2AFC01
# 850 2019-03-07 14:29:48    LotInfoDownLoad  2ACP03
# 851 2019-03-07 14:13:16           TrackOut  2ACP03
# 852 2019-03-07 13:39:00            TrackIn  2ACP03
# 853 2019-03-07 13:34:29    LotInfoDownLoad  2AMM01
# 854 2019-03-07 13:32:37          BackupEQP  2AMM01
# 855 2019-03-07 13:19:42      ChangeLotNote  2AMM01
# 856 2019-03-07 13:19:10           TrackOut  2AMM01
# 857 2019-03-07 13:03:43            TrackIn  2AMM01
# 858 2019-03-07 12:53:08    LotInfoDownLoad  2ATO09
# 859 2019-03-07 12:11:43           TrackOut  2ATO09
# 860 2019-03-07 11:53:02  ChangeLotPriority  2ATO09
# 861 2019-03-07 11:49:19            TrackIn  2ATO09
# 862 2019-03-07 11:46:29    LotInfoDownLoad  2AOV01
# 863 2019-03-07 11:33:46           TrackOut  2AOV01
# 864 2019-03-07 06:27:37            TrackIn  2AOV01
# 865 2019-03-07 06:27:30    LotInfoDownLoad  2AIC03
# 866 2019-03-07 06:24:35           TrackOut  2AIC03
# 867 2019-03-07 04:03:02            TrackIn  2AIC03
# 868 2019-03-07 00:58:35    LotInfoDownLoad  2AMP01
# 869 2019-03-06 23:51:02      ChangeLotNote  2AMP01
# 870 2019-03-06 23:15:16           TrackOut  2AMP01
# 871 2019-03-06 23:04:26            TrackIn  2AMP01
# 872 2019-03-06 23:04:11    LotInfoDownLoad  2AUU01
# 873 2019-03-06 19:59:18      ChangeLotNote  2AUU01
# 874 2019-03-06 19:56:28           TrackOut  2AUU01
# 875 2019-03-06 19:56:27            TrackIn  2AUU01
# 876 2019-03-06 19:56:26            Release  2AUU01
# 877 2019-03-06 16:50:04             Create     NaN
#
# [878 rows x 3 columns]

# %% [markdown]
# ##  确定 Ship 的时间，之后的TrackIn和TrackOut都不在Array，将之后的信息都剔除掉

# %%
shipidx = int(dfo[dfo['EventName'] == 'Ship'].index.values)
dfo = dfo.iloc[shipidx:]
dfo
# Out:
#               EventTime             EventName  EQP ID
# 35  2019-04-03 11:03:57                  Ship  2ASS01
# 36  2019-04-03 10:12:55              TrackOut  2ASS01
# 37  2019-04-03 10:12:45       DeassignCarrier  2ASS01
# 38  2019-04-03 10:04:04               TrackIn  2ASS01
# 39  2019-04-03 10:02:46       LotInfoDownLoad  2ATV01
# 40  2019-04-03 10:01:23  CreateSortJob, Split  2ATV01
# 41  2019-04-03 10:00:27      ChangeFlowToSort  2ATV01
# 42  2019-04-03 08:54:27              TrackOut  2ATV01
# 43  2019-04-03 08:40:53               TrackIn  2ATV01
# 44  2019-04-03 08:40:19              TrackOut  2ATO09
# 45  2019-04-03 07:55:22               TrackIn  2ATO09
# 46  2019-04-03 05:48:19       LotInfoDownLoad  2ATE02
# 47  2019-04-03 05:39:39           ReleaseHold  2ATE02
# 48  2019-04-03 05:16:31         ChangeLotNote  2ATE02
# 49  2019-04-03 05:14:40                  Hold  2ATE02
# 50  2019-04-03 05:14:39              TrackOut  2ATE02
# 51  2019-04-03 01:53:10               TrackIn  2ATE02
# 52  2019-04-03 01:52:54       LotInfoDownLoad  2AOV08
# 53  2019-04-03 01:46:16              TrackOut  2AOV08
# 54  2019-04-03 00:11:20               TrackIn  2AOV08
# 55  2019-04-03 00:11:04       LotInfoDownLoad  2ATO07
# 56  2019-04-03 00:03:50           ReleaseHold  2ATO07
# 57  2019-04-02 23:47:45         ChangeLotNote  2ATO07
# 58  2019-04-02 23:03:30         ChangeLotNote  2ATO07
# 59  2019-04-02 22:56:41                  Hold  2ATO07
# 60  2019-04-02 22:56:40              TrackOut  2ATO07
# 61  2019-04-02 22:47:57               TrackIn  2ATO07
# 62  2019-04-02 22:32:00       LotInfoDownLoad  2AMC04
# 63  2019-04-02 22:19:51           ForceSample  2AMC04
# 64  2019-04-02 22:19:48         ChangeLotNote  2AMC04
# ..                  ...                   ...     ...
# 848 2019-03-07 16:24:06              TrackOut  2AFC01
# 849 2019-03-07 14:32:03               TrackIn  2AFC01
# 850 2019-03-07 14:29:48       LotInfoDownLoad  2ACP03
# 851 2019-03-07 14:13:16              TrackOut  2ACP03
# 852 2019-03-07 13:39:00               TrackIn  2ACP03
# 853 2019-03-07 13:34:29       LotInfoDownLoad  2AMM01
# 854 2019-03-07 13:32:37             BackupEQP  2AMM01
# 855 2019-03-07 13:19:42         ChangeLotNote  2AMM01
# 856 2019-03-07 13:19:10              TrackOut  2AMM01
# 857 2019-03-07 13:03:43               TrackIn  2AMM01
# 858 2019-03-07 12:53:08       LotInfoDownLoad  2ATO09
# 859 2019-03-07 12:11:43              TrackOut  2ATO09
# 860 2019-03-07 11:53:02     ChangeLotPriority  2ATO09
# 861 2019-03-07 11:49:19               TrackIn  2ATO09
# 862 2019-03-07 11:46:29       LotInfoDownLoad  2AOV01
# 863 2019-03-07 11:33:46              TrackOut  2AOV01
# 864 2019-03-07 06:27:37               TrackIn  2AOV01
# 865 2019-03-07 06:27:30       LotInfoDownLoad  2AIC03
# 866 2019-03-07 06:24:35              TrackOut  2AIC03
# 867 2019-03-07 04:03:02               TrackIn  2AIC03
# 868 2019-03-07 00:58:35       LotInfoDownLoad  2AMP01
# 869 2019-03-06 23:51:02         ChangeLotNote  2AMP01
# 870 2019-03-06 23:15:16              TrackOut  2AMP01
# 871 2019-03-06 23:04:26               TrackIn  2AMP01
# 872 2019-03-06 23:04:11       LotInfoDownLoad  2AUU01
# 873 2019-03-06 19:59:18         ChangeLotNote  2AUU01
# 874 2019-03-06 19:56:28              TrackOut  2AUU01
# 875 2019-03-06 19:56:27               TrackIn  2AUU01
# 876 2019-03-06 19:56:26               Release  2AUU01
# 877 2019-03-06 16:50:04                Create     NaN
#
# [843 rows x 3 columns]

# %% [markdown]
# ## 先找到Ship的时间，再与之前创建往2AUU01搬送job的时间算差值，即为在Array的总时长

# %%
ship_time = dfo[dfo['EventName'] == 'Ship']['EventTime']
sumtime = (ship_time - AUU_start)
print(' %s 在 Array 总的时间为：%s ' % (Lotid, sum_time.iloc[0]))
# Out:
#  L2E9306A5AA 在 Array 总的时间为：27 days 15:46:58.091000

# %% [markdown]
# # 计算制程时间

# %% [markdown]
# ### 找到所有TrackIn的时间（只是为了防止出错，增加的验证步骤，不在代码中）

# %%
dftki = dfo[dfo['EventName'] == 'TrackIn']
print(dftki.shape)
dftki.head()
# Out:
# (171, 2)
#              EventTime EventName
# 38 2019-04-03 10:04:04   TrackIn
# 43 2019-04-03 08:40:53   TrackIn
# 45 2019-04-03 07:55:22   TrackIn
# 51 2019-04-03 01:53:10   TrackIn
# 54 2019-04-03 00:11:20   TrackIn

# %% [markdown]
# ### 找到所有TrackOut的时间（只是为了防止出错，增加的验证步骤，不在代码中）

# %%
dftho = dfo[dfo['EventName'] == 'TrackOut']
print(dftho.shape)
dftho.head()
# Out:
# (171, 2)
#              EventTime EventName
# 36 2019-04-03 10:12:55  TrackOut
# 42 2019-04-03 08:54:27  TrackOut
# 44 2019-04-03 08:40:19  TrackOut
# 50 2019-04-03 05:14:39  TrackOut
# 53 2019-04-03 01:46:16  TrackOut

# %% [markdown]
# ### 这一步的思路和上面的统计transertime一样，TrackOut TrackIn求差值再求和

# %%
dfo_time = pd.DataFrame()
dfo_time['tki'] = dfo[dfo['EventName'] == 'TrackIn']['EventTime'].tolist()
dfo_time['tko'] = dfo[dfo['EventName'] == 'TrackOut']['EventTime'].tolist()
dfo_time = dfo_time.astype(np.datetime64)
dfo_time['delta'] = dfo_time['tko'] - dfo_time['tki']
runtime = dfo_time['delta'].sum()
print('%s 在 Array 总的制程时间为 ： %s' % (Lotid, runtime))
# Out:
# L2E9306A5AA 在 Array 总的制程时间为 ： 7 days 01:59:38

# %% [markdown]
# ## 减法计算出waittime

# %%
waittime = (sumtime - trantime - runtime).iloc[0]
print('%s 在 Array 总的等待时间为：% s' % (Lotid, waittime))
# Out:
# L2E9306A5AA 在 Array 总的等待时间为：18 days 23:49:25.753000

# %% [markdown]
# # 转换数据后绘图

# %% [markdown]
# ## 把时间单位都转化成秒，便于绘图

# %%
s_runtime = runtime.total_seconds()
s_trantime = trantime.total_seconds()
s_waittime = waittime.total_seconds()
print(s_runtime, s_trantime, s_waittime)
# Out:
# 611978.0 136674.338 1640965.753

# %%
from pyecharts import Pie

attr = ["制程时间", "搬送时间", "等待时间"]
s_time = [s_runtime, s_trantime, s_waittime]
pie = Pie(('%s在Array总时长%s' % (Lotid, sumtime.iloc[0])), width=900, height=500,  title_pos='center', title_text_size=21)
pie.add("", attr, s_time, 
        is_label_show=True,
        radius=[45, 70], 
        legend_pos = 'right',
        legend_orient = 'vertical',
        label_text_size=19, legend_text_size=15)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="161ffa2a9847410bb237657427afe6ce" style="width:900px;height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_161ffa2a9847410bb237657427afe6ce = echarts.init(document.getElementById('161ffa2a9847410bb237657427afe6ce'), 'light', {renderer: 'canvas'});
#
# var option_161ffa2a9847410bb237657427afe6ce = {
#     "title": [
#         {
#             "text": "L2E9306A5AA\u5728Array\u603b\u65f6\u957f27 days 15:46:58.091000",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 21
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2075841,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u5236\u7a0b\u65f6\u95f4",
#                     "value": 611978.0
#                 },
#                 {
#                     "name": "\u642c\u9001\u65f6\u95f4",
#                     "value": 136674.338
#                 },
#                 {
#                     "name": "\u7b49\u5f85\u65f6\u95f4",
#                     "value": 1640965.753
#                 }
#             ],
#             "radius": [
#                 "45%",
#                 "70%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 19
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 2075841
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5236\u7a0b\u65f6\u95f4",
#                 "\u642c\u9001\u65f6\u95f4",
#                 "\u7b49\u5f85\u65f6\u95f4"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "right",
#             "top": "top",
#             "orient": "vertical",
#             "textStyle": {
#                 "fontSize": 15
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_161ffa2a9847410bb237657427afe6ce.setOption(option_161ffa2a9847410bb237657427afe6ce);
#
#     });
# </script>

# %%
df = dfo
df
# Out:
#               EventTime             EventName  EQP ID
# 35  2019-04-03 11:03:57                  Ship  2ASS01
# 36  2019-04-03 10:12:55              TrackOut  2ASS01
# 37  2019-04-03 10:12:45       DeassignCarrier  2ASS01
# 38  2019-04-03 10:04:04               TrackIn  2ASS01
# 39  2019-04-03 10:02:46       LotInfoDownLoad  2ATV01
# 40  2019-04-03 10:01:23  CreateSortJob, Split  2ATV01
# 41  2019-04-03 10:00:27      ChangeFlowToSort  2ATV01
# 42  2019-04-03 08:54:27              TrackOut  2ATV01
# 43  2019-04-03 08:40:53               TrackIn  2ATV01
# 44  2019-04-03 08:40:19              TrackOut  2ATO09
# 45  2019-04-03 07:55:22               TrackIn  2ATO09
# 46  2019-04-03 05:48:19       LotInfoDownLoad  2ATE02
# 47  2019-04-03 05:39:39           ReleaseHold  2ATE02
# 48  2019-04-03 05:16:31         ChangeLotNote  2ATE02
# 49  2019-04-03 05:14:40                  Hold  2ATE02
# 50  2019-04-03 05:14:39              TrackOut  2ATE02
# 51  2019-04-03 01:53:10               TrackIn  2ATE02
# 52  2019-04-03 01:52:54       LotInfoDownLoad  2AOV08
# 53  2019-04-03 01:46:16              TrackOut  2AOV08
# 54  2019-04-03 00:11:20               TrackIn  2AOV08
# 55  2019-04-03 00:11:04       LotInfoDownLoad  2ATO07
# 56  2019-04-03 00:03:50           ReleaseHold  2ATO07
# 57  2019-04-02 23:47:45         ChangeLotNote  2ATO07
# 58  2019-04-02 23:03:30         ChangeLotNote  2ATO07
# 59  2019-04-02 22:56:41                  Hold  2ATO07
# 60  2019-04-02 22:56:40              TrackOut  2ATO07
# 61  2019-04-02 22:47:57               TrackIn  2ATO07
# 62  2019-04-02 22:32:00       LotInfoDownLoad  2AMC04
# 63  2019-04-02 22:19:51           ForceSample  2AMC04
# 64  2019-04-02 22:19:48         ChangeLotNote  2AMC04
# ..                  ...                   ...     ...
# 848 2019-03-07 16:24:06              TrackOut  2AFC01
# 849 2019-03-07 14:32:03               TrackIn  2AFC01
# 850 2019-03-07 14:29:48       LotInfoDownLoad  2ACP03
# 851 2019-03-07 14:13:16              TrackOut  2ACP03
# 852 2019-03-07 13:39:00               TrackIn  2ACP03
# 853 2019-03-07 13:34:29       LotInfoDownLoad  2AMM01
# 854 2019-03-07 13:32:37             BackupEQP  2AMM01
# 855 2019-03-07 13:19:42         ChangeLotNote  2AMM01
# 856 2019-03-07 13:19:10              TrackOut  2AMM01
# 857 2019-03-07 13:03:43               TrackIn  2AMM01
# 858 2019-03-07 12:53:08       LotInfoDownLoad  2ATO09
# 859 2019-03-07 12:11:43              TrackOut  2ATO09
# 860 2019-03-07 11:53:02     ChangeLotPriority  2ATO09
# 861 2019-03-07 11:49:19               TrackIn  2ATO09
# 862 2019-03-07 11:46:29       LotInfoDownLoad  2AOV01
# 863 2019-03-07 11:33:46              TrackOut  2AOV01
# 864 2019-03-07 06:27:37               TrackIn  2AOV01
# 865 2019-03-07 06:27:30       LotInfoDownLoad  2AIC03
# 866 2019-03-07 06:24:35              TrackOut  2AIC03
# 867 2019-03-07 04:03:02               TrackIn  2AIC03
# 868 2019-03-07 00:58:35       LotInfoDownLoad  2AMP01
# 869 2019-03-06 23:51:02         ChangeLotNote  2AMP01
# 870 2019-03-06 23:15:16              TrackOut  2AMP01
# 871 2019-03-06 23:04:26               TrackIn  2AMP01
# 872 2019-03-06 23:04:11       LotInfoDownLoad  2AUU01
# 873 2019-03-06 19:59:18         ChangeLotNote  2AUU01
# 874 2019-03-06 19:56:28              TrackOut  2AUU01
# 875 2019-03-06 19:56:27               TrackIn  2AUU01
# 876 2019-03-06 19:56:26               Release  2AUU01
# 877 2019-03-06 16:50:04                Create     NaN
#
# [843 rows x 3 columns]

# %%
df.drop_duplicates('EQP ID')
# Out:
#               EventTime           EventName  EQP ID
# 35  2019-04-03 11:03:57                Ship  2ASS01
# 39  2019-04-03 10:02:46     LotInfoDownLoad  2ATV01
# 44  2019-04-03 08:40:19            TrackOut  2ATO09
# 46  2019-04-03 05:48:19     LotInfoDownLoad  2ATE02
# 52  2019-04-03 01:52:54     LotInfoDownLoad  2AOV08
# 55  2019-04-03 00:11:04     LotInfoDownLoad  2ATO07
# 62  2019-04-02 22:32:00     LotInfoDownLoad  2AMC04
# 73  2019-04-02 20:46:08   CancelReserveHold  2APP01
# 77  2019-04-02 17:31:02     LotInfoDownLoad  2AMS03
# 98  2019-04-02 09:41:19         ReserveHold  2AOV10
# 104 2019-04-02 06:57:56     LotInfoDownLoad  2AMM03
# 111 2019-04-02 05:13:17     LotInfoDownLoad  2APP05
# 114 2019-04-02 03:50:47     LotInfoDownLoad  2AES01
# 117 2019-04-02 01:49:55     LotInfoDownLoad  2AEW01
# 120 2019-04-02 00:23:20     LotInfoDownLoad  2AMM05
# 124 2019-04-01 23:23:43     LotInfoDownLoad  2APP02
# 135 2019-04-01 19:40:14     LotInfoDownLoad  2AMM01
# 139 2019-04-01 18:47:13     LotInfoDownLoad  2AFS05
# 142 2019-04-01 16:31:09     LotInfoDownLoad  2AED02
# 148 2019-04-01 13:07:43     LotInfoDownLoad  2APP03
# 151 2019-04-01 10:55:52     LotInfoDownLoad  2ATB01
# 160 2019-04-01 07:52:40     LotInfoDownLoad  2AES03
# 163 2019-04-01 06:39:39     LotInfoDownLoad  2AED12
# 169 2019-04-01 01:01:04         ReserveHold  2AMR01
# 175 2019-03-31 22:37:40     LotInfoDownLoad  2AFS03
# 179 2019-03-31 21:02:26     LotInfoDownLoad  2ACP03
# 186 2019-03-31 17:29:17     LotInfoDownLoad  2AMS01
# 192 2019-03-31 10:38:06     LotInfoDownLoad  2ATO01
# 204 2019-03-31 08:42:41     LotInfoDownLoad  2ATO10
# 208 2019-03-31 07:39:25     LotInfoDownLoad  2AES04
# ..                  ...                 ...     ...
# 400 2019-03-21 13:26:21  ChangedJobDownFlag  2AES02
# 423 2019-03-21 03:14:51     LotInfoDownLoad  2APP06
# 460 2019-03-20 20:32:02     LotInfoDownLoad  2AED08
# 471 2019-03-20 08:56:37     LotInfoDownLoad  2AOV05
# 516 2019-03-19 20:50:39     LotInfoDownLoad  2AMA04
# 523 2019-03-19 19:13:40                Warn  2AED04
# 532 2019-03-19 11:22:42     LotInfoDownLoad  2AFS01
# 564 2019-03-15 08:23:29     LotInfoDownLoad  2AFC08
# 575 2019-03-15 03:34:09     LotInfoDownLoad  2AEI01
# 632 2019-03-13 20:33:07     LotInfoDownLoad  2AMM09
# 636 2019-03-13 19:52:45     LotInfoDownLoad  2AMC02
# 648 2019-03-13 01:25:31     LotInfoDownLoad  2ATO14
# 694 2019-03-10 19:41:05     LotInfoDownLoad  2AFC07
# 697 2019-03-10 17:40:43     LotInfoDownLoad  2ATR07
# 728 2019-03-10 08:52:03     LotInfoDownLoad  2AED01
# 743 2019-03-10 01:44:22     LotInfoDownLoad  2AMF01
# 751 2019-03-09 19:45:11     LotInfoDownLoad  2AMA02
# 756 2019-03-09 18:38:45     LotInfoDownLoad  2AFE05
# 775 2019-03-09 05:52:48     LotInfoDownLoad  2AMA01
# 780 2019-03-09 03:48:39     LotInfoDownLoad  2AFC06
# 803 2019-03-08 15:31:45     LotInfoDownLoad  2AFC02
# 806 2019-03-08 13:12:37     LotInfoDownLoad  2ATO05
# 821 2019-03-08 10:30:52     LotInfoDownLoad  2ACP01
# 836 2019-03-08 03:45:23     LotInfoDownLoad  2AOV01
# 839 2019-03-07 22:14:00     LotInfoDownLoad  2AIC02
# 847 2019-03-07 17:49:31     LotInfoDownLoad  2AFC01
# 865 2019-03-07 06:27:30     LotInfoDownLoad  2AIC03
# 868 2019-03-07 00:58:35     LotInfoDownLoad  2AMP01
# 872 2019-03-06 23:04:11     LotInfoDownLoad  2AUU01
# 877 2019-03-06 16:50:04              Create     NaN
#
# [66 rows x 3 columns]
